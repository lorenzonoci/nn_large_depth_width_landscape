# %%
import torch
import os
import numpy as np
import re
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
def checkpoint_epoch(folder, epoch=19):
    files = os.listdir(folder)
    f = [f for f in files if "batches_{}_.pth".format(epoch) in f]
    if len(f) > 0:
        return f[0]
    return -1
def add_metadata(fname, d):
    match = re.search('width_mult_\d+', fname)
    if match:
        width_mult = match.group(0)[len("width_mult_"):]
        d["width_mult"] = int(width_mult)
    match = re.search('-lr_\d+.\d+', fname)
    if match:
        value = match.group(0)[len("-lr_"):]
        d["lr"] = float(value)
    match = re.search('-depth_mult_\d+', fname)
    if match:
        value = match.group(0)[len("-depth_mult_"):]
        d["depth_mult"] = int(value)
    match = re.search('-parametr_mup_depth', fname)
    if match:
        d["mup_depth"] = True
    else:
        d["mup_depth"] = False
    match = re.search('skip_scaling_\d+(\.\d+)?', fname)
    if match:
        value = match.group(0)[len("skip_scaling_"):]
        d["skip_scaling"] = float(value)
    else:
        d["skip_scaling"] = 1.0
    match = re.search('res_scaling_\d+(\.\d+)?', fname)
    if match:
        value = match.group(0)[len("res_scaling_"):]
        d["res_scaling"] = float(value)
    else:
        d["res_scaling"] = 1.0
    match = re.search('epoch_\d+', fname)
    if match:
        width_mult = match.group(0)[len("epoch_"):]
        d["epochs"] = int(width_mult)
    match = re.search('beta_\d+(\.\d+)?', fname)
    if match:
        value = match.group(0)[len("beta_"):]
        d["beta"] = float(value)
    else:
        d["beta"] = 1.0
    match = re.search('gamma_zero_\d+(\.\d+)?', fname)
    if match:
        value = match.group(0)[len("gamma_zero_"):]
        d["gamma_zero"] = float(value)
    else:
        d["gamma_zero"] = 1.0
    match = re.search('seed_\d+', fname)
    if match:
        s = match.group(0)[len("seed_"):]
        d["seed"] = int(s)
    else:
        d["seed"] = None
    match = re.search('-norm_ln', fname)
    if match:
        d["norm"] = "ln"
    elif re.search('-norm_bn', fname):
        d["norm"] = "ln"
    elif re.search('-norm_None', fname):
        d["norm"] = None
    else:
        d["norm"] = None
    match = re.search('parametr_', fname)
    if match:
        d['parametr'] = match.group(0)[len("parametr_"):]
    match = re.search('k_layers_\d+', fname)
    if match:
        value = match.group(0)[len("k_layers_"):]
        d["k_layers"] = int(value)
    else:
        d["k_layers"] = None
    match = re.search('batch_size_\d+', fname)
    if match:
        value = match.group(0)[len("batch_size_"):]
        d["batch_size"] = int(value)
    else:
        d["batch_size"] = None
    return d
def get_data(folder_path, epoch=19):
    final_d = []
    for fp in os.listdir(folder_path):
        fpath = os.path.join(folder_path, fp)
        d_file = checkpoint_epoch(fpath, epoch=epoch)
        if d_file != -1:
            fpath = os.path.join(fpath, checkpoint_epoch(fpath, epoch=epoch))
            d = torch.load(fpath)
            d = add_metadata(fp, d)
            d["name"] = fp
            final_d.append(d)
    return final_d
def loss_curves(run_ds, train=True, acc=True, neigs=1, nepochs=40):
    ds = []
    for d in run_ds:
        loss_d = pd.DataFrame()
        # try:
        if train:
            loss_d["train_loss"] =  d["metrics"]["train_loss"]
            # loss_d["residual"] = d["metrics"]["residual"]
            # loss_d["top_eig_ggn"] = d["metrics"]["top_eig_ggn"]
            # d["metrics"]["directional_sharpness"].insert(0, float('nan'))

            if acc:
                if "train_acc" in d["metrics"].keys():
                    loss_d["train_acc"] =  d["metrics"]["train_acc"]
            if "trace" in d["metrics"].keys() and len(d["metrics"]["trace"]) > 1:
                loss_d["trace"] = d["metrics"]["trace"]
            if "top_eig" in d["metrics"].keys() and len(d["metrics"]["top_eig"]) > 1:
                loss_d["top_eig"] = d["metrics"]["top_eig"]
        else:
            loss_d["test_loss"] =  d["metrics"]["test_loss"]
            loss_d["test_acc"] =  d["metrics"]["test_acc"]
        loss_d["lr"] = d["lr"]
        loss_d["seed"] = d["seed"]
        loss_d["width_mult"] = d["width_mult"]
        loss_d["depth_mult"] = d["depth_mult"]
        if neigs>1:
            for eigi in range(neigs):
                loss_d[f"top_eig_{eigi}"] =  d["metrics"][f"top_eig_{eigi}"]
                loss_d[f"ntk_eig_{eigi}"] =  d["metrics"][f"ntk_eig_{eigi}"]
        else:
            loss_d[f"top_eig_0"] =  d["metrics"][f"top_eig_0"]
        
        loss_d["step"] = loss_d.index
        loss_d["Epoch"] = (loss_d.index / loss_d.index.max()) * nepochs
        loss_d["beta"] = d["beta"]
        # loss_d["directional_sharpness"] = d["metrics"]["directional_sharpness"]
        loss_d["gamma_zero"] = d["gamma_zero"]
        loss_d["k_layers"] = d["k_layers"]
        loss_d["batch_size"] = d["batch_size"]
        ds.append(loss_d)
        # except KeyError:
        #     continue
    return pd.concat(ds, axis=0)
def get_metrics_df(run_ds, metric):
    ds = []
    for d in run_ds:
        try:
            d[metric] = d['metrics'][metric][-1]
            l = [metric, 'trace', 'seed', 'directional_sharpness', 'lr', 'width_mult', 'depth_mult', 'mup_depth', 'norm', 'gamma_zero', 'beta', 'k_layers', 'batch_size']
            if neigs > 1:
                for eigi in range(10):
                    l.append(f'top_eig_{eigi}')
                    l.append(f'ntk_eig_{eigi}')
            else:
                d.append('top_eig_0')
            d = {k: d[k] for k in l}
            ds.append(d)
        except KeyError as e:
            print(e)
            continue
    return pd.DataFrame(ds)

# %%
sns.set(style="whitegrid", font_scale=2.0, palette=sns.color_palette("rocket", n_colors=5))
plt.figure(figsize = (10,6))
folder_path = "/home/ameterez/work/nips2024/debug_depth_more_warmup_very_long_top10"
metric = "train_loss"
epochs = 79
run_ds = get_data(folder_path, epoch=epochs)
df = loss_curves(run_ds, acc=False, neigs=1, nepochs=epochs).reset_index()

# %%
lrs = sorted(df.lr.unique())
print(lrs)
# Out:
# [0.1, 0.128439, 0.164965, 0.211879, 0.272134, 0.349525, 0.448925, 0.576593, 0.740568, 0.951176, 1.221677, 1.569106, 2.015338, 2.588472, 3.324598]

# %%
df
# Out:
#        index  train_loss     trace        lr  seed  width_mult  depth_mult  \
# 0          0         NaN  0.037862  0.740568     5           1           1
# 1          1    2.304382  0.128860  0.740568     5           1           1
# 2          2    1.962942  0.809768  0.740568     5           1           1
# 3          3    1.757722  0.944491  0.740568     5           1           1
# 4          4    1.596035  1.297678  0.740568     5           1           1
# ...      ...         ...       ...       ...   ...         ...         ...
# 14818     76         NaN       NaN  3.324598     5           1           1
# 14819     77         NaN       NaN  3.324598     5           1           1
# 14820     78         NaN       NaN  3.324598     5           1           1
# 14821     79         NaN       NaN  3.324598     5           1           1
# 14822     80         NaN       NaN  3.324598     5           1           1
#
#        top_eig_0  step    Epoch  beta  gamma_zero  k_layers batch_size  Depth
# 0       0.006081     0   0.0000   1.0         1.0         2       None      3
# 1       0.025301     1   0.9875   1.0         1.0         2       None      3
# 2       0.153428     2   1.9750   1.0         1.0         2       None      3
# 3       0.061897     3   2.9625   1.0         1.0         2       None      3
# 4       0.086418     4   3.9500   1.0         1.0         2       None      3
# ...          ...   ...      ...   ...         ...       ...        ...    ...
# 14818        NaN    76  75.0500   1.0         1.0         2       None      3
# 14819        NaN    77  76.0375   1.0         1.0         2       None      3
# 14820        NaN    78  77.0250   1.0         1.0         2       None      3
# 14821        NaN    79  78.0125   1.0         1.0         2       None      3
# 14822        NaN    80  79.0000   1.0         1.0         2       None      3
#
# [14823 rows x 15 columns]

# %%
df['Depth'] = df['depth_mult'] * 3
df2 = df[df['step'] == df['step'].max()]
df2 = df2[df2['k_layers'] == 2]
palette=sns.color_palette("viridis", n_colors=len(df2['depth_mult'].unique()))
fig, ax = plt.subplots(ncols=1, nrows=1)
sns.lineplot(df2, x='lr', y='train_loss', hue='Depth', ax=ax, marker='o', palette=palette)
sns.move_legend(ax, loc='upper left', bbox_to_anchor=(1, 1.04))
ax.set_ylabel('Train Loss')
ax.set_xlabel('Learning Rate')
ax.set_xscale('log')
ax.set_yscale('log')
# ax.set_ylim(1.1, 2.0)
# ax.set_xlim(right=2e-2)
# fig.savefig('conv_cifar10_musgd_2_per_block_transfer.pdf', bbox_inches='tight')
fig.show()

# %%
# palette=sns.color_palette("viridis", n_colors=5)
# df2 = df[df['lr'] == lrs[4]]
# # df2['top_eig'] *= 32
# # df2['top_eig'] = df2.groupby(['seed', 'Depth'])['top_eig'].transform(lambda x: x.rolling(window=2, min_periods=1).mean())
# eig = 0
# df2[f'ntk_eig_{eig}'] *= (df2['width_mult'])

# fig, ax = plt.subplots(ncols=1, nrows=1)
# palettes = [sns.color_palette('viridis', 6)]
# sns.lineplot(df2, x='Epoch', y=f'ntk_eig_{eig}', hue='width_mult', style='lr', ax=ax, palette=palettes[0], legend=True)
# sns.move_legend(ax, loc='upper left', bbox_to_anchor=(1, 1))
# ax.set_yscale('log')
# # ax.set_ylim(6e-2)
# ax.set_ylabel('$\lambda_0$')
# # fig.savefig('conv_cifar10_muadam_no_scaling_sharpness_2_per_block.pdf', bbox_inches='tight')
# fig.show()

# %%
# nlayers = 2
df2 = df[df['lr'] == lrs[11]]
df2 = df2[df2['k_layers'] == 2]
palette=sns.color_palette("viridis", n_colors=len(df2['depth_mult'].unique()))
df['Depth'] = df['depth_mult'] * 3
df2['top_eig_0'] *= 64
# df2['top_eig'] *= 32
df2['top_eig_0'] = df2.groupby(['seed', 'depth_mult'])['top_eig_0'].transform(lambda x: x.rolling(window=2, min_periods=1).mean())

# df2['top_eig'] *= (1 / np.sqrt(df2['depth_mult']))
# df2['Learning Rate'] = df2['lr']
df2['lr'] = np.round(df2['lr'], 2)
fig, ax = plt.subplots(ncols=1, nrows=1)
sns.lineplot(df2, x='Epoch', y=f'top_eig_0', hue='Depth', style='lr', ax=ax, palette=palette, legend=True)
sns.move_legend(ax, loc='upper left', bbox_to_anchor=(1, 1.04))
ax.set_yscale('log')
# ax.set_ylim(bottom=5e-3)
ax.set_ylabel('$\lambda$')
fig.savefig('conv_cifar10_musgd_2_per_block_sharpness.pdf', bbox_inches='tight')
fig.show()

# %%
palette=sns.color_palette("viridis", n_colors=4)
# nlayers = 2
df2 = df[df['lr'] == lrs[8]]
df2 = df2[df2['k_layers'] == 2]
# df2['top_eig'] *= 32
# df2['top_eig_0'] = df2.groupby(['seed', 'depth_mult'])['top_eig_0'].transform(lambda x: x.rolling(window=2, min_periods=1).mean())

# df2['top_eig'] *= (1 / np.sqrt(df2['depth_mult']))

fig, ax = plt.subplots(ncols=1, nrows=1)
palettes = [sns.color_palette('viridis', 5)]
sns.lineplot(df2, x='Epoch', y=f'trace', hue='depth_mult', style='lr', ax=ax, palette=palettes[0], legend=True)
sns.move_legend(ax, loc='upper left', bbox_to_anchor=(1, 1))
ax.set_yscale('log')
ax.set_ylim(bottom=5e-1)
ax.set_ylabel('$\lambda$')
# fig.savefig('conv_cifar10_muadam_no_scaling_sharpness_2_per_block.pdf', bbox_inches='tight')
fig.show()

# %%
### lrs[9]
# Out:
# 0.464159

# %%
palette=sns.color_palette("viridis", n_colors=6)
df2 = df[df['lr'] == lrs[9]]
df2['Width'] = df2['width_mult'] * 64
df3 = df2.melt(var_name='$\lambda_i(\Theta)$', value_name='ntk_eigenvalues', value_vars=['ntk_eig_0', 'ntk_eig_4'], id_vars=['seed', 'Width', 'lr', 'Epoch'])
df3 = df3.replace({'ntk_eig_0': '$\lambda_0$', 'ntk_eig_4': '$\lambda_4$',})
# df3['eigenvalue'] = df3.groupby(['seed', 'Width', '$\lambda_i$'])['eigenvalue'].rolling(2).mean()

df3['ntk_eigenvalues'] *= df3['Width']
fig, ax = plt.subplots(ncols=1, nrows=1)
# make new df

sns.lineplot(df3, x='Epoch', y=f'ntk_eigenvalues', hue='Width', style='$\lambda_i(\Theta)$', ax=ax, palette=palette, legend=True)
sns.move_legend(ax, loc='upper left', bbox_to_anchor=(1, 1))
ax.set_yscale('log')
# ax.set_ylim(1e-2)
ax.set_ylabel('$\lambda$')
# fig.savefig('conv_cifar10_top_eigs_sharpness.pdf', bbox_inches='tight')
fig.show()
# Out:
# /tmp/ipykernel_3640648/1437506335.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['Width'] = df2['width_mult'] * 64
